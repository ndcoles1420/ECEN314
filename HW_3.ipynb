# %% [markdown]
# <a href="https://colab.research.google.com/github/ndcoles1420/ECEN314/blob/main/HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check homogenous solution for question 1
from sympy import *
t = symbols('t')
x = Function('x')
y = Function('y')

dy = diff(y(t), t) + y(t)
dsolve(dy, y(t))
# Out:
# Eq(y(t), C1*exp(-t))

# %%
# Q3 output
y = exp(-t)
plot(y, (t, -5, 5))

# %%
# Q4 output
y = exp(-t) + sin(t) - cos(t)
yoft = Piecewise ((0, t < pi/2), (y, True))
plot(yoft)
